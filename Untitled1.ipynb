# %%
# Réexécution du pipeline complet après réinitialisation de l'état
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score

# %%
# Définition des chemins des fichiers
file_heart_exams = "DSA-2024_HeartDisease_HeartExams_20240312.tsv"
file_diagnosis = "DSA-2024_HeartDisease_Diagnosis_20240312.csv"
file_general_exams = "DSA-2024_HeartDisease_GeneralExams_20240312.tsv"

# %%
# 1. Chargement des fichiers
df_heart_exams = pd.read_csv(file_heart_exams, sep="\t")
df_diagnosis = pd.read_csv(file_diagnosis)
df_general_exams = pd.read_csv(file_general_exams, sep="\t")

# %%
# %run CATALOGUE.ipynb

# %%
decrire_colonnes(df_heart_exams)
# Out:
#   Nom de la colonne Type de données  Valeurs manquantes  \
# 0        patient_id          object                   0
# 1       measurement          object                   0
# 2             value         float64                   0
#
#    Pourcentage de valeurs manquantes  Valeurs uniques
# 0                               0.00             1190
# 1                               0.00                6
# 2                               0.00              172

# %%
decrire_colonnes(df_general_exams)
# Out:
#          Nom de la colonne Type de données  Valeurs manquantes  \
# 0                center_id          object                   0
# 1               patient_id          object                   0
# 2                      sex          object                   0
# 3                   weight         float64                  70
# 4                   height         float64                  54
# 5             resting.bp.s           int64                   0
# 6              cholesterol           int64                   0
# 7      fasting.blood.sugar           int64                   0
# 8        physical_activity          object                   0
# 9                      dob          object                   0
# 10  social_security_number           int64                   0
#
#     Pourcentage de valeurs manquantes  Valeurs uniques
# 0                                0.00                1
# 1                                0.00             1190
# 2                                0.00                4
# 3                                5.88              471
# 4                                4.54               96
# 5                                0.00               67
# 6                                0.00              222
# 7                                0.00                2
# 8                                0.00                4
# 9                                0.00               50
# 10                               0.00             1190

# %%
decrire_colonnes(df_diagnosis)
# Out:
#   Nom de la colonne Type de données  Valeurs manquantes  \
# 0               pid           int64                   0
# 1            target          object                   0
#
#    Pourcentage de valeurs manquantes  Valeurs uniques
# 0                               0.00             1190
# 1                               0.00                2

# %%
generer_catalogue(df_heart_exams)
# Out:
# ===== DESCRIPTION DES COLONNES =====
#   Nom de la colonne Type de données  Valeurs manquantes  \
# 0        patient_id          object                   0
# 1       measurement          object                   0
# 2             value         float64                   0
#
#    Pourcentage de valeurs manquantes  Valeurs uniques
# 0                               0.00             1190
# 1                               0.00                6
# 2                               0.00              172
#
# ===== STATISTIQUES DESCRIPTIVES =====
#         value
# count 7140.00
# mean    24.43
# std     52.62
# min     -2.60
# 25%      0.00
# 50%      1.70
# 75%      4.00
# max    202.00

# %%
generer_catalogue(df_heart_exams)
# Out:
# ===== DESCRIPTION DES COLONNES =====
#   Nom de la colonne Type de données  Valeurs manquantes  \
# 0        patient_id          object                   0
# 1       measurement          object                   0
# 2             value         float64                   0
#
#    Pourcentage de valeurs manquantes  Valeurs uniques
# 0                               0.00             1190
# 1                               0.00                6
# 2                               0.00              172
#
# ===== STATISTIQUES DESCRIPTIVES =====
#         value
# count 7140.00
# mean    24.43
# std     52.62
# min     -2.60
# 25%      0.00
# 50%      1.70
# 75%      4.00
# max    202.00

# %%
generer_catalogue(df_general_exams)
# Out:
# ===== DESCRIPTION DES COLONNES =====
#          Nom de la colonne Type de données  Valeurs manquantes  \
# 0                center_id          object                   0
# 1               patient_id          object                   0
# 2                      sex          object                   0
# 3                   weight         float64                  70
# 4                   height         float64                  54
# 5             resting.bp.s           int64                   0
# 6              cholesterol           int64                   0
# 7      fasting.blood.sugar           int64                   0
# 8        physical_activity          object                   0
# 9                      dob          object                   0
# 10  social_security_number           int64                   0
#
#     Pourcentage de valeurs manquantes  Valeurs uniques
# 0                                0.00                1
# 1                                0.00             1190
# 2                                0.00                4
# 3                                5.88              471
# 4                                4.54               96
# 5                                0.00               67
# 6                                0.00              222
# 7                                0.00                2
# 8                                0.00                4
# 9                                0.00               50
# 10                               0.00             1190
#
# ===== STATISTIQUES DESCRIPTIVES =====
#        weight  height  resting.bp.s  cholesterol  fasting.blood.sugar  \
# count 1120.00 1136.00       1190.00      1190.00              1190.00
# mean    74.45  173.16        132.15       210.36                 0.21
# std     15.95   20.66         18.37       101.42                 0.41
# min     46.10    1.58          0.00         0.00                 0.00
# 25%     61.20  162.00        120.00       188.00                 0.00
# 50%     75.00  174.00        130.00       229.00                 0.00
# 75%     87.72  185.00        140.00       269.75                 0.00
# max    101.90  233.00        200.00       603.00                 1.00
#
#        social_security_number
# count                 1190.00
# mean          210745197506.17
# std            36866357040.00
# min           146594225469.00
# 25%           178269901652.75
# 50%           211844747505.50
# 75%           240805664706.50
# max           274520233098.00

# %%
# 2. Nettoyage et transformation
df_heart_exams = df_heart_exams.dropna()
df_diagnosis = df_diagnosis.dropna()
df_general_exams = df_general_exams.drop(columns=["social_security_number"], errors='ignore')  # Suppression de données sensibles

# %%
# Conversion de `dob` en âge
current_year = pd.to_datetime("today").year
df_general_exams["age"] = current_year - pd.to_datetime(df_general_exams["dob"]).dt.year
df_general_exams = df_general_exams.drop(columns=["dob"])

# %%
df_general_exams
# Out:
#        center_id patient_id sex  weight  height  resting.bp.s  cholesterol  \
# 0     HOSPIT4224   PAT00001   M    49.9   174.0           140          289
# 1     HOSPIT4224   PAT00002   F    65.3   180.0           160          180
# 2     HOSPIT4224   PAT00003   M    65.5     NaN           130          283
# 3     HOSPIT4224   PAT00004   F    77.9   160.0           138          214
# 4     HOSPIT4224   PAT00005   M    98.3   175.0           150          195
# ...          ...        ...  ..     ...     ...           ...          ...
# 1185  HOSPIT4224   PAT01186   M    84.3   185.0           110          264
# 1186  HOSPIT4224   PAT01187   M    75.8   171.0           144          193
# 1187  HOSPIT4224   PAT01188   M    71.9   185.0           130          131
# 1188  HOSPIT4224   PAT01189   F    56.4   189.0           130          236
# 1189  HOSPIT4224   PAT01190   M    81.4   176.0           138          175
#
#       fasting.blood.sugar physical_activity  age
# 0                       0               Low   41
# 1                       0               Low   50
# 2                       0      Intermediate   38
# 3                       0               Low   49
# 4                       0               Low   55
# ...                   ...               ...  ...
# 1185                    0               Low   46
# 1186                    1               Low   69
# 1187                    0               Low   58
# 1188                    0               Low   58
# 1189                    0               Low   39
#
# [1190 rows x 10 columns]

# %%
# Transformation des colonnes catégoriques
df_general_exams["sex"] = df_general_exams["sex"].map({'M': 1, 'F': 0})
df_general_exams["physical_activity"] = df_general_exams["physical_activity"].map({'Low': 0, 'Intermediate': 1, 'High': 2})

# %%
# Renommage des clés pour fusion
df_diagnosis = df_diagnosis.rename(columns={"pid": "patient_id"})
df_diagnosis["patient_id"] = df_diagnosis["patient_id"].astype(str)
df_heart_exams["patient_id"] = df_heart_exams["patient_id"].astype(str)
df_general_exams["patient_id"] = df_general_exams["patient_id"].astype(str)

# %%
# 3. Fusion des datasets
df_fusionne = df_general_exams.merge(df_diagnosis, on="patient_id", how="left")
df_heart_exams_pivot = df_heart_exams.pivot(index="patient_id", columns="measurement", values="value").reset_index()
df_fusionne = df_fusionne.merge(df_heart_exams_pivot, on="patient_id", how="left")

# %%
df_heart_exams_pivot
# Out:
# measurement patient_id  ST.slope  chest.pain.type  exercise.angina  \
# 0             PAT00001       1.0              2.0              0.0
# 1             PAT00002       2.0              3.0              0.0
# 2             PAT00003       1.0              2.0              0.0
# 3             PAT00004       2.0              4.0              1.0
# 4             PAT00005       1.0              3.0              0.0
# ...                ...       ...              ...              ...
# 1185          PAT01186       2.0              1.0              0.0
# 1186          PAT01187       2.0              4.0              0.0
# 1187          PAT01188       2.0              4.0              1.0
# 1188          PAT01189       2.0              2.0              0.0
# 1189          PAT01190       1.0              3.0              0.0
#
# measurement  max.heart.rate  oldpeak  resting.ecg
# 0                     172.0      0.0          0.0
# 1                     156.0      1.0          0.0
# 2                      98.0      0.0          1.0
# 3                     108.0      1.5          0.0
# 4                     122.0      0.0          0.0
# ...                     ...      ...          ...
# 1185                  132.0      1.2          0.0
# 1186                  141.0      3.4          0.0
# 1187                  115.0      1.2          0.0
# 1188                  174.0      0.0          2.0
# 1189                  173.0      0.0          0.0
#
# [1190 rows x 7 columns]

# %%
df_fusionne
# Out:
#        center_id patient_id  sex  weight  height  resting.bp.s  cholesterol  \
# 0     HOSPIT4224   PAT00001  1.0    49.9   174.0           140          289
# 1     HOSPIT4224   PAT00002  0.0    65.3   180.0           160          180
# 2     HOSPIT4224   PAT00003  1.0    65.5     NaN           130          283
# 3     HOSPIT4224   PAT00004  0.0    77.9   160.0           138          214
# 4     HOSPIT4224   PAT00005  1.0    98.3   175.0           150          195
# ...          ...        ...  ...     ...     ...           ...          ...
# 1185  HOSPIT4224   PAT01186  1.0    84.3   185.0           110          264
# 1186  HOSPIT4224   PAT01187  1.0    75.8   171.0           144          193
# 1187  HOSPIT4224   PAT01188  1.0    71.9   185.0           130          131
# 1188  HOSPIT4224   PAT01189  0.0    56.4   189.0           130          236
# 1189  HOSPIT4224   PAT01190  1.0    81.4   176.0           138          175
#
#       fasting.blood.sugar  physical_activity  age target  ST.slope  \
# 0                       0                0.0   41    NaN       1.0
# 1                       0                0.0   50    NaN       2.0
# 2                       0                1.0   38    NaN       1.0
# 3                       0                0.0   49    NaN       2.0
# 4                       0                0.0   55    NaN       1.0
# ...                   ...                ...  ...    ...       ...
# 1185                    0                0.0   46    NaN       2.0
# 1186                    1                0.0   69    NaN       2.0
# 1187                    0                0.0   58    NaN       2.0
# 1188                    0                0.0   58    NaN       2.0
# 1189                    0                0.0   39    NaN       1.0
#
#       chest.pain.type  exercise.angina  max.heart.rate  oldpeak  resting.ecg
# 0                 2.0              0.0           172.0      0.0          0.0
# 1                 3.0              0.0           156.0      1.0          0.0
# 2                 2.0              0.0            98.0      0.0          1.0
# 3                 4.0              1.0           108.0      1.5          0.0
# 4                 3.0              0.0           122.0      0.0          0.0
# ...               ...              ...             ...      ...          ...
# 1185              1.0              0.0           132.0      1.2          0.0
# 1186              4.0              0.0           141.0      3.4          0.0
# 1187              4.0              1.0           115.0      1.2          0.0
# 1188              2.0              0.0           174.0      0.0          2.0
# 1189              3.0              0.0           173.0      0.0          0.0
#
# [1190 rows x 17 columns]

# %%
# 4. Normalisation des colonnes numériques
numerical_cols = df_fusionne.select_dtypes(include=['int64', 'float64']).columns.tolist()
scaler = MinMaxScaler()
df_fusionne[numerical_cols] = scaler.fit_transform(df_fusionne[numerical_cols])

# %%
catalogue = DataCatalogue(df_fusionne)
catalogue.generate_catalogue()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 catalogue = DataCatalogue(df_fusionne)
#       2 catalogue.generate_catalogue()
#
# NameError: name 'DataCatalogue' is not defined

# %%
df_fusionne.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   center_id            1190 non-null   object
#  1   patient_id           1190 non-null   object
#  2   sex                  1186 non-null   float64
#  3   weight               1120 non-null   float64
#  4   height               1136 non-null   float64
#  5   resting.bp.s         1190 non-null   float64
#  6   cholesterol          1190 non-null   float64
#  7   fasting.blood.sugar  1190 non-null   float64
#  8   physical_activity    1185 non-null   float64
#  9   age                  1190 non-null   int32
#  10  target               0 non-null      object
#  11  ST.slope             1190 non-null   float64
#  12  chest.pain.type      1190 non-null   float64
#  13  exercise.angina      1190 non-null   float64
#  14  max.heart.rate       1190 non-null   float64
#  15  oldpeak              1190 non-null   float64
#  16  resting.ecg          1190 non-null   float64
# dtypes: float64(13), int32(1), object(3)
# memory usage: 153.5+ KB

# %% [markdown]
# ### Cette fonction utilise GridSearchCV pour tester différentes combinaisons d'hyperparamètres et trouver les meilleures valeurs.
